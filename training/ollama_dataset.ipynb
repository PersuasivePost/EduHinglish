# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/EduHinglish-ollama
# Out:
# /content/drive/MyDrive/EduHinglish-ollama

# %%
# !ls
# !ls trainin
# !ls data
# Out:
# data  trainin
# enrich_hinglish.py
# ss9.json

# %%
# !apt-get update -qq
# !apt-get install -y zstd
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 77 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 1s (474 kB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 122579 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import subprocess
import time

ollama_process = subprocess.Popen(
    ["ollama", "serve"],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE
)

time.sleep(5)

# !ollama list
# Out:
# NAME    ID    SIZE    MODIFIED

# %%
# !nvidia-smi
# Out:
# Sun Aug 30 18:33:31 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !ollama pull qwen3:8b

# %%
# !ollama run qwen3:8b "Explain the water cycle in simple Hinglish for a Class 9 student."
# Out:
# Thinking...
# Okay, so I need to explain the water cycle in simple Hinglish for a Class 9
# 9 student. Let me start by recalling what the water cycle is. The water cyc
# cycle, also known as the hydrological cycle, involves the continuous moveme
# movement of water on, above, and below the surface of the Earth. The main p
# processes are evaporation, condensation, precipitation, and collection.
#
# First, I should break down each step into simple terms. Let me think about
# how to translate these terms into Hinglish. For example, "evaporation" coul
# could be "पानी ऊपर उठता है" (water goes up). "Condensation" is when water v
# vapor turns back into liquid, so maybe "बादल बनते हैं" (clouds form). "Prec
# "Precipitation" is when water falls as rain, snow, etc., so "बरसात या हिमपा
# हिमपात होता है" (rain or snow happens). "Collection" would be when water coll
# collects in bodies like rivers, lakes, or oceans, so "पानी नदियों, झीलों या
# या सागर में जाता है" (water goes to rivers, lakes, or seas).
#
# I need to make sure the explanation is in simple Hinglish, using common wor
# words and avoiding complex terms. Also, the structure should be clear and e
# easy to follow. Maybe start with the sun heating water, then evaporation, f
# forming clouds, precipitation, and then the cycle continues. I should check
# check if there's any specific terminology that's commonly used in Class 9 t
# textbooks to align with their curriculum. Also, including examples like oce
# oceans, lakes, rivers, and even plants (transpiration) might be helpful. Wa
# Wait, transpiration is when plants release water vapor, so maybe mention th
# that as part of evaporation.
#
# Let me structure it step by step. Start with the sun's role, then evaporati
# evaporation from different sources (oceans, lakes, plants), condensation fo
# forming clouds, precipitation, and then collection back into water bodies.
# Then mention that the cycle repeats. Use simple sentences and maybe some em
# emojis if allowed, but since the user didn't specify, maybe avoid. Also, ch
# check for any possible confusion. For example, making sure the student unde
# understands that the cycle is continuous and not a one-time process.
#
# Let me put it all together in Hinglish, keeping each part short and clear.
# Use terms like "ऊष्मा" (heat), "बादल" (clouds), "बरसात" (rain), "नदी" (rive
# (river), etc. Avoid technical jargon. Make sure the explanation flows logic
# logically from one step to the next. Maybe use bullet points or numbered st
# steps, but since it's a simple explanation, perhaps a paragraph with clear
# transitions.
#
# Wait, the user said "simple Hinglish," so maybe use some Hindi words mixed
# with English. For example, "Evaporation" could be "उबलना" (boiling), but th
# that's not accurate. Alternatively, "पानी ऊपर उठता है" (water goes up). May
# Maybe use "ऊष्मा" for heat, "वाष्प" for vapor, "बादल" for clouds, "बरसात" f
# for rain.
#
# Let me draft the explanation step by step, ensuring each part is simple and
# and clear. Check for any possible misunderstandings. For instance, making s
# sure that the student knows that after precipitation, the water doesn't jus
# just disappear but flows back into water bodies. Also, mention that the cyc
# cycle is endless. Alright, I think that's a solid plan. Now, time to put it
# it all together in Hinglish.
# ...done thinking.
#
# **पानी के चक्र (Water Cycle) की सरल व्याख्या (Hinglish):**
#
# पृथ्वी पर पानी के चक्र के बारे में जानिए! यह एक निरंतर चक्र है जहां पानी पृ
# पृथ्वी के विभिन्न स्थानों के बीच घूमता रहता है। इसे **जल चक्र** भी कहते हैं।
# हैं।
#
# 1. **ऊष्मा से उबलना (Evaporation):**
#    सूरज की ऊष्मा के कारण, नदियों, झीलों, सागरों और बर्फ के टुकड़ों में जल उ
# उबलता है और **वाष्प** (गैस के रूप में) ऊपर उठता है। बगीचों में पौधे भी अपना
# अपना पानी वाष्प के रूप में छोड़ते हैं (इसे **अपस्थानन** कहते हैं)।
#
# 2. **बादल बनना (Condensation):**
#    ऊपर उठे वाष्प ठंडा होता है और छोटे बूंदों में बदल जाता है। ये बूंदें आका
# आकाश में **बादल** बनाती हैं।
#
# 3. **बरसात होना (Precipitation):**
#    जब बादल बहुत भारी हो जाते हैं, तो वे बरसात, हिमपात या बर्फ के रूप में पृ
# पृथ्वी पर गिर जाते हैं।
#
# 4. **जल एकत्र होना (Collection):**
#    बरसात के बाद, पानी नदियों, झीलों, सागरों या भूमि में जमा हो जाता है। फिर
# फिर इस पानी का चक्र फिर से शुरू हो जाता है।
#
# **संक्षेप में:**
# सूरज की ऊष्मा से पानी ऊपर उठता है, बादल बनते हैं, फिर बरसात होती है और पानी
# पानी नदियों में जाता है। इस चक्र के कारण पृथ्वी पर हमेशा पानी रहता है! 🌧️💧
#
#
# **तो, पानी का चक्र किस तरह चलता है?**
# ऊष्मा → वाष्प → बादल → बरसात → नदी/सागर → फिर ऊष्मा के कारण फिर से शुरू! 🌍
# ✨

# %%
# !ollama run qwen3:8b "Explain photosynthesis in simple Hinglish in two sentences."
# Out:
# Thinking...
# Okay, the user wants an explanation of photosynthesis in simple Hinglish, i
# in two sentences. Let me start by recalling what photosynthesis is. Plants
# use sunlight to make their food, right? They take in carbon dioxide and wat
# water, and with sunlight, they produce glucose and oxygen.
#
# Now, translating that into Hinglish. Hinglish is a mix of Hindi and English
# English, so I need to use common Hindi words with English terms. Let me bre
# break it down. "Photosynthesis" is "फोटोसंश्लेषण" in Hindi, but maybe using
# using "sunlight" as "सूरज की किरण" or "सूरज की ऊर्जा".
#
# First sentence: Plants use sunlight to make their food. In Hinglish, that c
# could be "पौधे सूरज की किरणों का उपयोग करके अपना खाना बनाते हैं।" But maybe
# maybe "सूरज की ऊर्जा" is better. So, "पौधे सूरज की ऊर्जा का उपयोग करके अपना
# अपना खाना बनाते हैं।"
#
# Second sentence: They take in carbon dioxide and water, and release oxygen.
# oxygen. In Hinglish, that would be "वे कार्बन डाइऑक्साइड और पानी लेते हैं,
# और ऑक्सीजन छोड़ देते हैं।" But maybe using "हवा में लेते हैं" for carbon di
# dioxide. Wait, "carbon dioxide" is "कार्बन डाइऑक्साइड", so maybe "वे कार्बन
# कार्बन डाइऑक्साइड और पानी लेते हैं, और ऑक्सीजन छोड़ देते हैं।"
#
# Wait, the user might not know the exact terms, so maybe using simpler words
# words. Like "वे हवा में लेते हैं और पानी लेते हैं, फिर ऑक्सीजन छोड़ देते है
# हैं।" But that's not accurate. Let me check again. The process involves taki
# taking in CO2 and water, using sunlight to create glucose and oxygen. So th
# the second sentence should mention both inputs and the output.
#
# Putting it all together: First sentence about using sunlight to make food.
# Second sentence about taking in CO2 and water, releasing oxygen. That's two
# two sentences. Let me make sure the Hinglish is simple and clear. Maybe use
# use "सूरज की ऊर्जा" for sunlight, "कार्बन डाइऑक्साइड" for carbon dioxide, a
# and "ऑक्सीजन" for oxygen.
#
# So the two sentences would be:
# 1. पौधे सूरज की ऊर्जा का उपयोग करके अपना खाना बनाते हैं।
# 2. वे कार्बन डाइऑक्साइड और पानी लेते हैं, और ऑक्सीजन छोड़ देते हैं।
#
# That should cover the main points in simple Hinglish.
# ...done thinking.
#
# 1. पौधे सूरज की ऊर्जा का उपयोग करके अपना खाना बनाते हैं।
# 2. वे कार्बन डाइऑक्साइड और पानी लेते हैं, और ऑक्सीजन छोड़ देते हैं।

# %%
# !ollama run qwen3:8b "hi" &
import time; time.sleep(3)
# !ollama ps
# Out:
# Thinking...
# okay, the user said "hi /think". first, i need to acknowledge their greetin
# greeting. since they included "/think", maybe they're testing if i can proc
# process that command. but in the context of a conversation, it's more likel
# likely they just meant to say hello. i should respond politely and offer as
# assistance. let me make sure to keep the tone friendly and open-ended. mayb
# maybe ask how i can help them today. that should cover it.
# ...done thinking.
#
# Hello! How can I assist you today? 😊
#
# NAME        ID              SIZE      PROCESSOR    CONTEXT    UNTIL
# qwen3:8b    500a1f067a9f    5.6 GB    100% GPU     4096       4 minutes from now

# %%
# !python training/enrich_hinglish.py --input data/ss9.json --backend ollama --model qwen3:8b --concurrency 1 --limit 1
# Out:
# [EduHinglish Enrichment] -> ss9.json
#   Backend    : ollama
#   Model      : qwen3:8b
#   Concurrency: 1
#   Checkpoint : every 20 entries
#
#   Total entries : 4247
#   Already filled: 8
#   To process    : 1 (limited to 1)
#
#   [1/1] checkpoint saved  |  0.1 entries/s  |  ~0.0 min remaining
#
# Done! Enriched 1 entries -> /content/drive/MyDrive/EduHinglish-ollama/data/ss9.json

# %%
# !python training/enrich_hinglish.py --input data/ss9.json --backend ollama --model qwen3:8b --concurrency 2 --save-every 20
# Out:
# [EduHinglish Enrichment] -> ss9.json
#   Backend    : ollama
#   Model      : qwen3:8b
#   Concurrency: 2
#   Checkpoint : every 20 entries
#
#   Total entries : 4247
#   Already filled: 9
#   To process    : 4238
#
#   [ollama error] HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180) — retrying...
#   [ollama error] HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180) — retrying...
#   [ollama error] HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180) — retrying...
#   [ollama error] HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180) — retrying...
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/asyncio/runners.py", line 119, in run
#     return self._loop.run_until_complete(task)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/usr/lib/python3.13/asyncio/base_events.py", line 726, in run_until_complete
#     return future.result()
#            ~~~~~~~~~~~~~^^
#   File "/content/drive/MyDrive/EduHinglish-ollama/training/enrich_hinglish.py", line 248, in run
#     results = await asyncio.gather(*tasks)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/EduHinglish-ollama/training/enrich_hinglish.py", line 195, in enrich_entry
#     q_hi = await ollama_generate(ctx["host"], ctx["model_name"], q_prompt)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/EduHinglish-ollama/training/enrich_hinglish.py", line 174, in ollama_generate
#     return await asyncio.to_thread(_ollama_generate_sync, host, model_name, prompt)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/asyncio/threads.py", line 26, in to_thread
#     return await loop.run_in_executor(None, func_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/asyncio/runners.py", line 196, in run
#     return runner.run(main)
#            ~~~~~~~~~~^^^^^^
#   File "/usr/lib/python3.13/asyncio/runners.py", line 124, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/EduHinglish-ollama/training/enrich_hinglish.py", line 297, in <module>
#     main()
#     ~~~~^^
#   File "/content/drive/MyDrive/EduHinglish-ollama/training/enrich_hinglish.py", line 293, in main
#     asyncio.run(run(inpath, args.backend, concurrency, args.save_every, model_name, args.ollama_host, args.limit))
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/asyncio/runners.py", line 195, in run
#     with Runner(debug=debug, loop_factory=loop_factory) as runner:
#          ~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/asyncio/runners.py", line 63, in __exit__
#     self.close()
#     ~~~~~~~~~~^^
#   File "/usr/lib/python3.13/asyncio/runners.py", line 73, in close
#     loop.run_until_complete(
#     ~~~~~~~~~~~~~~~~~~~~~~~^
#         loop.shutdown_default_executor(constants.THREAD_JOIN_TIMEOUT))
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/asyncio/base_events.py", line 713, in run_until_complete
#     self.run_forever()
#     ~~~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/asyncio/base_events.py", line 684, in run_forever
#     self._run_once()
#     ~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/asyncio/base_events.py", line 2061, in _run_once
#     handle._run()
#     ~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/asyncio/events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/asyncio/base_events.py", line 614, in shutdown_default_executor
#     thread.start()
#     ~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/threading.py", line 982, in start
#     self._started.wait()  # Will set ident and native_id
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/threading.py", line 660, in wait
#     signaled = self._cond.wait(timeout)
#   File "/usr/lib/python3.13/threading.py", line 359, in wait
#     waiter.acquire()
#     ~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# ^C
